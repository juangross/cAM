# %% [markdown]
# <a href="https://colab.research.google.com/github/juangross/cursoPDI2021/blob/main/PDI_TP3_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **consigna**: Implementar un aplicativo que ejecute las operaciones vistas en este tema.
# Se muestra la interfaz gráfica de un ejemplo en particular.
# bloque 1

# %%
#importo material de trabajo
# !git clone https://github.com/juangross/cursoPDI2021
# Out:
# fatal: destination path 'cursoPDI2021' already exists and is not an empty directory.

# %% [markdown]
# Bloque 2

# %%
import matplotlib.pyplot as plt
import imageio as img
import numpy as np

#cargo imágenes de prueba
# Import an image from directory:
path="./cursoPDI2021/imagenes/"
#archi="patron_RGBCMYWK"
archi1="río_uruguay_4"
archi2="milo6r"
#archi="río_uruguay_3"
#archi="río_uruguay_2"
ext="png"

#formato actual

#input_image= mpimg.imread(f"{archi}.{ext}")  #lee con matplotlib
Img1=img.imread(f"{path}{archi1}.{ext}")      #lee con imageio
Img2=img.imread(f"{path}{archi2}.{ext}")      #lee con imageio
input_tam=Img1.shape
print("leyendo archivo:", f"{path}{archi1}.{ext}", input_tam)
print("leyendo archivo:", f"{path}{archi2}.{ext}", Img2.shape)

#plt.subplot(1,2,1)
#plt.imshow(input_image)
#print(img1.shape)
#print(img2.shape)
# Out:
# leyendo archivo: ./cursoPDI2021/imagenes/río_uruguay_4.png (480, 853, 3)
# leyendo archivo: ./cursoPDI2021/imagenes/milo6r.png (480, 853, 3)

# %% [markdown]
# Suma RGB pura
# bloque 3

# %%
resultado=np.zeros(input_tam, dtype=float)

#calculo suma RGB de las imágenes
#resultado=img1+img2
Resultado=Img1.astype(np.float)+ Img2.astype(np.float)

plt.figure (dpi=200)
ax1=plt.subplot(1,3,1)
plt.imshow(Img1)
plt.title("Origen A")
#plt.setp(ax1.get_yticklabels(), fontsize=6)
#plt.setp(ax1.get_xticklabels(), fontsize=6)
plt.axis('off')

ax2=plt.subplot(1,3,2, sharey=ax1)
plt.imshow(Img2)
plt.title("Origen B")
#plt.setp(ax2.get_yticklabels(), visible=False)
#plt.setp(ax2.get_xticklabels(), fontsize=6)
plt.axis('off')

ax3= plt.subplot(1,3,3, sharey=ax1)
plt.imshow(Resultado)
plt.title("A + B ")
#plt.setp(ax3.get_yticklabels(), visible=False)
#plt.setp(ax3.get_xticklabels(), fontsize=6)
plt.axis('off')

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# bloque 3.1
# Resta pura RGB con recorte de valores

# %%
resultado=np.zeros(input_tam, dtype=float)

#calculo suma RGB de las imágenes
#resultado=img1+img2
Resultado=Img1.astype(np.float)- Img2.astype(np.float)

Resultado=np.clip(Resultado,0,255)#recorto los valores negativos

plt.figure (dpi=200)
ax1=plt.subplot(1,3,1)
plt.imshow(Img1)
plt.title("Origen A")
#plt.setp(ax1.get_yticklabels(), fontsize=6)
#plt.setp(ax1.get_xticklabels(), fontsize=6)
plt.axis('off')

ax2=plt.subplot(1,3,2, sharey=ax1)
plt.imshow(Img2)
plt.title("Origen B")
#plt.setp(ax2.get_yticklabels(), visible=False)
#plt.setp(ax2.get_xticklabels(), fontsize=6)
plt.axis('off')

ax3= plt.subplot(1,3,3, sharey=ax1)
plt.imshow(Resultado)
plt.title("A + B ")
#plt.setp(ax3.get_yticklabels(), visible=False)
#plt.setp(ax3.get_xticklabels(), fontsize=6)
plt.axis('off')

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# aquí se ve que la suma de las imágenes satura los canales

# %% [markdown]
# **Suma RGB con recorte de valores (Suma clampeada en RGB)**
#
# bloque 4

# %%
Resultado=np.zeros(input_tam, dtype=float)

#calculo suma RGB de las imágenes
#resultado=img1+img2
Resultado=Img1.astype(np.float) + Img2.astype(np.float)
#print(resultado)
Resultado=np.clip(Resultado,0,255.)
plt.figure (dpi=200)

ax1=plt.subplot(1,3,1)
plt.imshow(Img1)
plt.title("Origen A")
#plt.setp(ax1.get_yticklabels(), fontsize=6)
#plt.setp(ax1.get_xticklabels(), fontsize=6)
plt.axis('off')

ax2=plt.subplot(1,3,2, sharey=ax1)
plt.imshow(Img2)
plt.title("Origen B")
#plt.setp(ax2.get_yticklabels(), visible=False)
#plt.setp(ax2.get_xticklabels(), fontsize=6)
plt.axis('off')

ax3= plt.subplot(1,3,3, sharey=ax1)
plt.imshow(Resultado)
plt.title("A + B ")
#plt.setp(ax3.get_yticklabels(), visible=False)
#plt.setp(ax3.get_xticklabels(), fontsize=6)
plt.axis('off')

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# si luego de sumar las imágenes se hace un clip al rango 0-255, tampoco cambia el resultado respecto de la suma libre anterior

# %% [markdown]
# **Suma promedio en RGB**
#
# bloque 5

# %%
resultado=np.zeros(input_tam, dtype=float)


#calculo suma RGB de las imágenes previamente promediadas
Resultado=Img1.astype(np.float)/2+Img2.astype(np.float)/2
#print(resultado)
resultado=np.clip(resultado,0,255)
plt.figure (dpi=200)

ax1=plt.subplot(1,3,1)
plt.imshow(Img1)
plt.title("Origen A")
#plt.setp(ax1.get_yticklabels(), fontsize=6)
#plt.setp(ax1.get_xticklabels(), fontsize=6)
plt.axis('off')

ax2=plt.subplot(1,3,2, sharey=ax1)
plt.imshow(Img2)
plt.title("Origen B")
#plt.setp(ax2.get_yticklabels(), visible=False)
#plt.setp(ax2.get_xticklabels(), fontsize=6)
plt.axis('off')

ax3= plt.subplot(1,3,3, sharey=ax1)
plt.imshow(Resultado.astype('uint8'))
plt.title("A/2 + B/2 ")
#plt.setp(ax3.get_yticklabels(), visible=False)
#plt.setp(ax3.get_xticklabels(), fontsize=6)
plt.axis('off')

plt.show()

# %% [markdown]
# **Resta RGB promediada**
#
# bloque 6

# %%
Resultado=np.zeros(input_tam, dtype=float)


#calculo suma RGB de las imágenes previamente promediadas
Resultado=Img1.astype(np.float)/2 - Img2.astype(np.float)/2
#print(resultado)
Resultado=np.clip(Resultado,0,255)
plt.figure (dpi=200)

ax1=plt.subplot(1,3,1)
plt.imshow(Img1)
plt.title("Origen A")
#plt.setp(ax1.get_yticklabels(), fontsize=6)
#plt.setp(ax1.get_xticklabels(), fontsize=6)
plt.axis('off')

ax2=plt.subplot(1,3,2, sharey=ax1)
plt.imshow(Img2)
plt.title("Origen B")
#plt.setp(ax2.get_yticklabels(), visible=False)
#plt.setp(ax2.get_xticklabels(), fontsize=6)
plt.axis('off')

ax3= plt.subplot(1,3,3, sharey=ax1)
plt.imshow(Resultado.astype('uint8'))
plt.title("A/2 + B/2 ")
#plt.setp(ax3.get_yticklabels(), visible=False)
#plt.setp(ax3.get_xticklabels(), fontsize=6)
plt.axis('off')

plt.show()

# %% [markdown]
# Suma en YIQ - luminancia desacoplada - suma campleada
#
# bloque 7

# %%
input_tam=Img1.shape
Resultado=np.zeros(input_tam, dtype=float)
yiq3=np.zeros(input_tam, dtype=float)

#normalizo la imagen de entrada
nImg1=1/255*Img1 #la imagen queda en tipo float
nImg2=1/255*Img2 #la imagen queda en tipo float
#print(nResultado)


#transformo a 
def RGB_TO_YIQ(RGBImage ):
  #matriz de conversión de RGB -> YIQ
  RGB2YIQ=np.array([[0.299,0.587,0.114],[0.595716,-0.274453,-0.321263],[0.211456,-0.522591,0.311135]], dtype=float)

  #me baso en esta explicación del producto matricial para hacer la conversión de bases
  #https://stackoverflow.com/questions/46990838/numpy-transforming-rgb-image-to-yiq-color-space
  YIQ_image=np.zeros(RGBImage.shape, dtype=float)
  YIQ_image=np.dot(RGBImage,RGB2YIQ.T.copy())
  return YIQ_image

def YIQ_TO_RGB(YIQImage ):
  #matriz de conversión de RGB -> YIQ
  RGB2YIQ=np.array([[0.299,0.587,0.114],[0.595716,-0.274453,-0.321263],[0.211456,-0.522591,0.311135]], dtype=float)

  #me baso en esta explicación del producto matricial para hacer la conversión de bases
  #https://stackoverflow.com/questions/46990838/numpy-transforming-rgb-image-to-yiq-color-space
  RGB_image=np.zeros(YIQImage.shape, dtype=float)
  RGB_image=np.dot(YIQImage,RGB2YIQ.T.copy())
  return RGB_image


yiq1=RGB_TO_YIQ (nImg1)
yiq2=RGB_TO_YIQ (nImg2)

#sumo las imágenes con cada canal por separado
yiq3[:,:,0]=yiq1[:,:,0]+yiq2[:,:,0] #luego hay que recortar
#yiq3[:,:,0]=yiq1[:,:,0]/2+yiq2[:,:,0]/2 #suma el canal Y promediando
yiq3[:,:,1]=yiq1[:,:,1]+yiq2[:,:,1] 
yiq3[:,:,2]=yiq1[:,:,2]+yiq2[:,:,2] 

#recorto los valores extremos
#yiq3[:,:,0]=np.clip(yiq3[:,:,0],0,1) #recorto los valores Y
yiq3[:,:,1]=np.clip(yiq3[:,:,1],-.5957,.5957) #recorto los valores I
yiq3[:,:,1]=np.clip(yiq3[:,:,1],-.5226,.5226) #recorto los valores Q

#falta YIQ-> RGB
Img3= YIQ_TO_RGB(yiq3)

#desnormalizar
#desnormalizar RGB
Img3=255*Img3
Img3=np.rint(Img3)  #redondeo a valores enteros
Img3=np.clip(Img3,0,255) #recorto los valores que superen 255
#mostrar resultados

plt.figure (dpi=200)
ax1=plt.subplot(1,3,1)
plt.imshow(Img1)
plt.title("Origen A (YIQ)")
#plt.setp(ax1.get_yticklabels(), fontsize=6)
#plt.setp(ax1.get_xticklabels(), fontsize=6)
plt.axis('off')

ax2=plt.subplot(1,3,2, sharey=ax1)
plt.imshow(Img2)
plt.title("Origen B (YIQ)")
#plt.setp(ax2.get_yticklabels(), visible=False)
#plt.setp(ax2.get_xticklabels(), fontsize=6)
plt.axis('off')

ax3= plt.subplot(1,3,3, sharey=ax1)
plt.imshow(Img3.astype('uint8'))
plt.title("A(YIQ)/2 + B(YIQ)/2 ")
#plt.setp(ax3.get_yticklabels(), visible=False)
#plt.setp(ax3.get_xticklabels(), fontsize=6)
plt.axis('off')

plt.show()

# %% [markdown]
# Suma en YIQ - luminancia desacoplada - suma promediada
#
# bloque 8

# %%
input_tam=Img1.shape
Resultado=np.zeros(input_tam, dtype=float)
yiq3=np.zeros(input_tam, dtype=float)

#normalizo la imagen de entrada
nImg1=1/255*Img1 #la imagen queda en tipo float
nImg2=1/255*Img2 #la imagen queda en tipo float
#print(nResultado)


#transformo a YIQ
def RGB_TO_YIQ(RGBImage ):
  #matriz de conversión de RGB -> YIQ
  RGB2YIQ=np.array([[0.299,0.587,0.114],[0.595716,-0.274453,-0.321263],[0.211456,-0.522591,0.311135]], dtype=float)
  
  #print(RGBImage.dtype)

  #me baso en esta explicación del producto matricial para hacer la conversión de bases
  #https://stackoverflow.com/questions/46990838/numpy-transforming-rgb-image-to-yiq-color-space
  YIQ_image=np.zeros(RGBImage.shape, dtype=float)
  YIQ_image=np.dot(RGBImage,RGB2YIQ.T.copy())
  return YIQ_image

#transformo a RGB
def YIQ_TO_RGB(YIQImage):
  #matriz de conversión de RGB -> YIQ
  RGB2YIQ=np.array([[0.299,0.587,0.114],[0.595716,-0.274453,-0.321263],[0.211456,-0.522591,0.311135]], dtype=float)

  #print(YIQImage.dtype)
  #me baso en esta explicación del producto matricial para hacer la conversión de bases
  #https://stackoverflow.com/questions/46990838/numpy-transforming-rgb-image-to-yiq-color-space
  RGB_image=np.zeros(YIQImage.shape, dtype=float)
  RGB_image=np.dot(YIQImage,RGB2YIQ.T.copy())
  return RGB_image

#transformo las imágenes normalizadas al espacio de coordenadas YIQ
yiq1=RGB_TO_YIQ (nImg1)
yiq2=RGB_TO_YIQ (nImg2)

#sumo las imágenes con cada canal por separado
#yiq3[:,:,0]=yiq1[:,:,0]+yiq2[:,:,0] #luego hay que recortar
#yiq3[:,:,0]=yiq1[:,:,0]/2+yiq2[:,:,0]/2 #suma el canal Y promediando
yiq3[:,:,0]=0.5*yiq1[:,:,0]+0.5*yiq2[:,:,0] #suma el canal Y promediando
yiq3[:,:,1]=yiq1[:,:,1]+yiq2[:,:,1] 
yiq3[:,:,2]=yiq1[:,:,2]+yiq2[:,:,2] 

#recorto los valores extremos
#yiq3[:,:,0]=np.clip(yiq3[:,:,0],0,1) #recorto los valores Y
yiq3[:,:,1]=np.clip(yiq3[:,:,1],-.5957,.5957) #recorto los valores I
yiq3[:,:,1]=np.clip(yiq3[:,:,1],-.5226,.5226) #recorto los valores Q


Img4= YIQ_TO_RGB(yiq1)
Img5= YIQ_TO_RGB(yiq2)
Img3= YIQ_TO_RGB(yiq3)

#desnormalizar RGB
Img3=255*Img3
Img3=np.rint(Img3)  #redondeo a valores enteros
Img3=np.clip(Img3,0,255) #recorto los valores que superen 255

Img5=255*Img5
Img5=np.rint(Img5)  #redondeo a valores enteros
Img5=np.clip(Img5,0,255) #recorto los valores que superen 255

Img4=255*Img4
Img4=np.rint(Img4)  #redondeo a valores enteros
Img4=np.clip(Img4,0,255) #recorto los valores que superen 255


#mostrar resultados
plt.figure (dpi=200)
ax1=plt.subplot(1,3,1)
plt.imshow(Img1)
plt.title("Origen A (YIQ)")
#plt.setp(ax1.get_yticklabels(), fontsize=6)
#plt.setp(ax1.get_xticklabels(), fontsize=6)
plt.axis('off')

ax2=plt.subplot(1,3,2, sharey=ax1)
plt.imshow(Img4)
plt.title("Origen B (YIQ)")
#plt.setp(ax2.get_yticklabels(), visible=False)
#plt.setp(ax2.get_xticklabels(), fontsize=6)
plt.axis('off')

ax3= plt.subplot(1,3,3, sharey=ax1)
plt.imshow(Img3.astype('uint8'))
plt.title("A/2 + B/2 ")
#plt.setp(ax3.get_yticklabels(), visible=False)
#plt.setp(ax3.get_xticklabels(), fontsize=6)
plt.axis('off')

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# **Cuasi suma if-lighter**
#
# blqoue 9

# %%
input_tam=Img1.shape
Resultado=np.zeros(input_tam, dtype=float)
yiq3=np.zeros(input_tam, dtype=float)

#normalizo la imagen de entrada
nImg1=1/255*Img1 #la imagen queda en tipo float
nImg2=1/255*Img2 #la imagen queda en tipo float
#print(nResultado)


#transformo a YIQ
def RGB_TO_YIQ(RGBImage ):
  #matriz de conversión de RGB -> YIQ
  RGB2YIQ=np.array([[0.299,0.587,0.114],[0.595716,-0.274453,-0.321263],[0.211456,-0.522591,0.311135]], dtype=float)
  
  #print(RGBImage.dtype)

  #me baso en esta explicación del producto matricial para hacer la conversión de bases
  #https://stackoverflow.com/questions/46990838/numpy-transforming-rgb-image-to-yiq-color-space
  YIQ_image=np.zeros(RGBImage.shape, dtype=float)
  YIQ_image=np.dot(RGBImage,RGB2YIQ.T.copy())
  return YIQ_image

#transformo a RGB
def YIQ_TO_RGB(YIQImage):
  #matriz de conversión de RGB -> YIQ
  RGB2YIQ=np.array([[0.299,0.587,0.114],[0.595716,-0.274453,-0.321263],[0.211456,-0.522591,0.311135]], dtype=float)

  #print(YIQImage.dtype)
  #me baso en esta explicación del producto matricial para hacer la conversión de bases
  #https://stackoverflow.com/questions/46990838/numpy-transforming-rgb-image-to-yiq-color-space
  RGB_image=np.zeros(YIQImage.shape, dtype=float)
  RGB_image=np.dot(YIQImage,RGB2YIQ.T.copy())
  return RGB_image

#transformo las imágenes normalizadas al espacio de coordenadas YIQ
yiq1=RGB_TO_YIQ (nImg1)
yiq2=RGB_TO_YIQ (nImg2)


#acá va la lógica del if-lighter
#escribiendo mal, la idea es hacer algo así
#yiq3[:,:,0] = if (yiq1[:,:,0]> yiq2[:,:,0]: yiq1[:,:,0] else yiq2[:,:,0] )


mask1= np.greater_equal(yiq1[:,:,0], yiq2[:,:,0] )
#print(mask1)
#calculo la máscara complementaria, negando los valores de mask1
mask2= np.invert(mask1)
#mask2= np.less(yiq1[:,:,0], yiq2[:,:,0] )
#print(mask2)

#Yiq1_masked= mask1* yiq1[:,:,0] #mascara principal  (valores mayores)
#Yiq2_masked= mask2* yiq2[:,:,0] #mascara complementaria
#print(Yiq1_masked.shape)

#como funciona esto:
#en una de las mask1 siempre queda activo los valores mayores y en la otra los menores.

#yiq3[:,:,0]=Yiq1_masked[:,:] + Yiq2_masked[:,:]
yiq3[:,:,0]=mask1* yiq1[:,:,0] + mask2*yiq2[:,:,0]
yiq3[:,:,1]=mask1* yiq1[:,:,1] + mask2*yiq2[:,:,1] 
yiq3[:,:,2]=mask1* yiq1[:,:,2] + mask2*yiq2[:,:,2] 


#recorto los valores extremos
yiq3[:,:,0]=np.clip(yiq3[:,:,0],0,1) #recorto los valores Y
yiq3[:,:,1]=np.clip(yiq3[:,:,1],-.5957,.5957) #recorto los valores I
yiq3[:,:,1]=np.clip(yiq3[:,:,1],-.5226,.5226) #recorto los valores Q

Img3= YIQ_TO_RGB(yiq3)

#desnormalizar RGB
Img3=255*Img3
Img3=np.rint(Img3)  #redondeo a valores enteros
Img3=np.clip(Img3,0,255) #recorto los valores que superen 255


#mostrar resultados
plt.figure (dpi=200)
ax1=plt.subplot(1,3,1)
plt.imshow(Img1)
plt.title("Origen A (YIQ)")
#plt.setp(ax1.get_yticklabels(), fontsize=6)
#plt.setp(ax1.get_xticklabels(), fontsize=6)
plt.axis('off')

ax2=plt.subplot(1,3,2, sharey=ax1)
plt.imshow(Img2)
plt.title("Origen B (YIQ)")
#plt.setp(ax2.get_yticklabels(), visible=False)
#plt.setp(ax2.get_xticklabels(), fontsize=6)
plt.axis('off')

ax3= plt.subplot(1,3,3, sharey=ax1)
plt.imshow(Img3.astype('uint8'))
plt.title("if-lighter")
#plt.setp(ax3.get_yticklabels(), visible=False)
#plt.setp(ax3.get_xticklabels(), fontsize=6)
plt.axis('off')

plt.show()

# %% [markdown]
# **cuasi suma - if-darker**
#
# bloque 10

# %%
input_tam=Img1.shape
Resultado=np.zeros(input_tam, dtype=float)
yiq3=np.zeros(input_tam, dtype=float)

#normalizo la imagen de entrada
nImg1=1/255*Img1 #la imagen queda en tipo float
nImg2=1/255*Img2 #la imagen queda en tipo float
#print(nResultado)


#transformo a YIQ
def RGB_TO_YIQ(RGBImage ):
  #matriz de conversión de RGB -> YIQ
  RGB2YIQ=np.array([[0.299,0.587,0.114],[0.595716,-0.274453,-0.321263],[0.211456,-0.522591,0.311135]], dtype=float)
  
  #print(RGBImage.dtype)

  #me baso en esta explicación del producto matricial para hacer la conversión de bases
  #https://stackoverflow.com/questions/46990838/numpy-transforming-rgb-image-to-yiq-color-space
  YIQ_image=np.zeros(RGBImage.shape, dtype=float)
  YIQ_image=np.dot(RGBImage,RGB2YIQ.T.copy())
  return YIQ_image

#transformo a RGB
def YIQ_TO_RGB(YIQImage):
  #matriz de conversión de RGB -> YIQ
  RGB2YIQ=np.array([[0.299,0.587,0.114],[0.595716,-0.274453,-0.321263],[0.211456,-0.522591,0.311135]], dtype=float)

  #print(YIQImage.dtype)
  #me baso en esta explicación del producto matricial para hacer la conversión de bases
  #https://stackoverflow.com/questions/46990838/numpy-transforming-rgb-image-to-yiq-color-space
  RGB_image=np.zeros(YIQImage.shape, dtype=float)
  RGB_image=np.dot(YIQImage,RGB2YIQ.T.copy())
  return RGB_image

#transformo las imágenes normalizadas al espacio de coordenadas YIQ
yiq1=RGB_TO_YIQ (nImg1)
yiq2=RGB_TO_YIQ (nImg2)


#acá va la lógica del if-lighter
#escribiendo mal, la idea es hacer algo así
#yiq3[:,:,0] = if (yiq1[:,:,0]> yiq2[:,:,0]: yiq1[:,:,0] else yiq2[:,:,0] )


mask1= np.less_equal(yiq1[:,:,0], yiq2[:,:,0] )
#print(mask1)
#calculo la máscara complementaria, negando los valores de mask1
mask2= np.invert(mask1)
#mask2= np.less(yiq1[:,:,0], yiq2[:,:,0] )
#print(mask2)

#Yiq1_masked= mask1* yiq1[:,:,0] #mascara principal  (valores mayores)
#Yiq2_masked= mask2* yiq2[:,:,0] #mascara complementaria
#print(Yiq1_masked.shape)

#como funciona esto:
#en una de las mask1 siempre queda activo los valores mayores y en la otra los menores.

#yiq3[:,:,0]=Yiq1_masked[:,:] + Yiq2_masked[:,:]
yiq3[:,:,0]=mask1* yiq1[:,:,0] + mask2*yiq2[:,:,0]
yiq3[:,:,1]=mask1* yiq1[:,:,1] + mask2*yiq2[:,:,1] 
yiq3[:,:,2]=mask1* yiq1[:,:,2] + mask2*yiq2[:,:,2] 
#yiq3[:,:,1]=yiq1[:,:,1]+yiq2[:,:,1] 
#yiq3[:,:,2]=yiq1[:,:,2]+yiq2[:,:,2] 


#recorto los valores extremos
yiq3[:,:,0]=np.clip(yiq3[:,:,0],0,1) #recorto los valores Y
yiq3[:,:,1]=np.clip(yiq3[:,:,1],-.5957,.5957) #recorto los valores I
yiq3[:,:,1]=np.clip(yiq3[:,:,1],-.5226,.5226) #recorto los valores Q

Img3= YIQ_TO_RGB(yiq3)

#desnormalizar RGB
Img3=255*Img3
Img3=np.rint(Img3)  #redondeo a valores enteros
Img3=np.clip(Img3,0,255) #recorto los valores que superen 255


#mostrar resultados
plt.figure (dpi=200)
ax1=plt.subplot(1,3,1)
plt.imshow(Img1)
plt.title("Origen A (YIQ)")
#plt.setp(ax1.get_yticklabels(), fontsize=6)
#plt.setp(ax1.get_xticklabels(), fontsize=6)
plt.axis('off')

ax2=plt.subplot(1,3,2, sharey=ax1)
plt.imshow(Img2)
plt.title("Origen B (YIQ)")
#plt.setp(ax2.get_yticklabels(), visible=False)
#plt.setp(ax2.get_xticklabels(), fontsize=6)
plt.axis('off')

ax3= plt.subplot(1,3,3, sharey=ax1)
plt.imshow(Img3.astype('uint8'))
plt.title("if-darker")
#plt.setp(ax3.get_yticklabels(), visible=False)
#plt.setp(ax3.get_xticklabels(), fontsize=6)
plt.axis('off')

plt.show()

# %% [markdown]
# **bloque 11**, borrador - calculos de prueba

# %%
A=np.array([1,2,3,4])
B=np.array([2,2,1,2])
C=np.array([0,0,0,0])


print("matriz a: ",A)
print("matriz b: ",B)
print('\n')

mascara1=np.greater_equal(A,B)
mascara2=np.less(A,B)
print("mascara A>B: ", mascara1)
print("mascara A<B: ", mascara2)
print('\n')
#se ve que las mascaras se complementan entre ellas, eso me permite separar los valores mayores por un lado, y los menores por el otro

amask=A*mascara1 #amask contiene los valores de A
#bmask=B*mascara2
bmask=np.invert(mascara1)

print("matriz a: ",A)
print("matriz a enmascarada: ", amask)
print('\n')
print("matriz b: ",B)
print("matriz b enmascarada: ",bmask)
print('\n')

C =amask+bmask
print("matriz C: ",C) #en C quedan copiados solamente los valores mas grandes de A y B
# Out:
# matriz a:  [1 2 3 4]
# matriz b:  [2 2 1 2]
#
#
# mascara A>B:  [False  True  True  True]
# mascara A<B:  [ True False False False]
#
#
# matriz a:  [1 2 3 4]
# matriz a enmascarada:  [0 2 3 4]
#
#
# matriz b:  [2 2 1 2]
# matriz b enmascarada:  [ True False False False]
#
#
# matriz C:  [1 2 3 4]

# %%
archivo = "\"r\\xEDo_uruguay_1\""
import ipywidgets as widgets
from IPython.display import display
#button = widgets.Button(description="Click Me!")
archivos=[ ('río_uruguay_1',0),('río_uruguay_2',1),('río_uruguay_3',2),('río_uruguay_4',3)]
archivo1= widgets.Dropdown(
    options=archivos,
    Value=2,
    #description='Number:',
)
#output = widgets.Output()
display(archivo1)
print("seleccionó: ", archivo1.Value)
# Out:
# Dropdown(options=(('río_uruguay_1', 0), ('río_uruguay_2', 1), ('río_uruguay_3', 2), ('río_uruguay_4', 3)), val…
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-fa2a6671e628> in <module>()
#      10 #output = widgets.Output()
#      11 display(archivo1)
# ---> 12 print("seleccionó: ", archivo1.Value)
#
# AttributeError: 'Dropdown' object has no attribute 'Value'
